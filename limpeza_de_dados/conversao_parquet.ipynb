# %%
import pandas as pd


df = pd.read_csv('../Imdb_Movie_Dataset.csv', on_bad_lines='skip')
df_aux = df.copy()
# Out:
# Running cells with 'pw (Python 3.12.0)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: 'c:/Users/Lucas/Envs/pw/Scripts/python.exe -m pip install ipykernel -U --force-reinstall'

# %%
df_aux.to_parquet('../Imdb_Movie_Dataset.parquet', index=False, compression='zstd')
